# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
# from os.path import dirname, abspath
# d = os.path.dirname(os.getcwd())
d = os.getcwd()
print(d + '\\' + 'paperlist.tsv')
sns.set(style='darkgrid', context='talk', palette='colorblind')
# Out:
# d:\Study\code\NeurIPS2023-OpenReviewData\paperlist.tsv

# %% [markdown]
# ## Keywords

# %%
df = pd.read_csv(d + '\\' + 'paperlist.tsv', index_col=0, sep='\t')
print('# papers:', len(df))
df.head()
# Out:
# # papers: 3216
#                                                         title  \
# paper_id
# NnMEadcdyD  Understanding Diffusion Objectives as the ELBO...
# TXoZiUZywf  Improved Algorithms for Stochastic Linear Band...
# KvPwXVcslY  Spatial-frequency channels  shape bias  and ad...
# AOKU4nRw1W  Linguistic Binding in Diffusion Models: Enhanc...
# jDIlzSU8wJ  The Surprising Effectiveness of Diffusion Mode...
#
#                                                   link  \
# paper_id
# NnMEadcdyD  https://openreview.net/forum?id=NnMEadcdyD
# TXoZiUZywf  https://openreview.net/forum?id=TXoZiUZywf
# KvPwXVcslY  https://openreview.net/forum?id=KvPwXVcslY
# AOKU4nRw1W  https://openreview.net/forum?id=AOKU4nRw1W
# jDIlzSU8wJ  https://openreview.net/forum?id=jDIlzSU8wJ
#
#                                                      keywords  \
# paper_id
# NnMEadcdyD  Diffusion Model,Evidence Lower Bound,Maximum L...
# TXoZiUZywf  Linear bandits,confidence sequences,martingale...
# KvPwXVcslY  object recognition,critical band masking,spati...
# AOKU4nRw1W  syntax,diffusion,stable diffusion,attribute,at...
# jDIlzSU8wJ  Monocular depth,optical flow,diffusion,depth,flow
#
#                                                      abstract
# paper_id
# NnMEadcdyD  To achieve the highest perceptual quality, sta...
# TXoZiUZywf  We present improved algorithms with worst-case...
# KvPwXVcslY  What spatial frequency information do humans a...
# AOKU4nRw1W  Text-conditioned image generation models often...
# jDIlzSU8wJ  Denoising diffusion probabilistic models have ...

# %%
# counts = pd.Series(
#     ', '.join(df['keywords'].dropna()).lower().replace('-', ' ').replace('networks', 'network').split(',')
# ).str.strip().value_counts().sort_values(ascending=True)

counts = pd.Series(
    ', '.join(df['keywords'].dropna()).lower().replace('-', ' ').replace('networks', 'network').split(',')
).str.strip().value_counts().sort_values(ascending=True)
counts.iloc[-50:].plot.barh(figsize=(8, 12), title='ICLR 2023 Submission Top 50 Keywords')
plt.savefig(d + '\\' +'assets\\keywords.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig(d + '\\' + 'assets\\wordcloud.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

logo = imread('asset/logo.png')
wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0, mask=logo)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(logo)
plt.imshow(wc, interpolation="bilinear", alpha=.75)
plt.axis("off")
plt.savefig(d + '\\' + 'assets\\logo_wordcloud.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\Academic\AppData\Local\Temp\ipykernel_59308\1036031717.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   logo = imread('asset/logo.png')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 4
#       1 from imageio import imread
#       2 from wordcloud import WordCloud
# ----> 4 logo = imread('asset/logo.png')
#       5 wc = WordCloud(background_color="white", max_words=300, max_font_size=64,
#       6                width=1280, height=640, random_state=0, mask=logo)
#       7 wc.generate_from_frequencies(counts.to_dict())
#
# File c:\Python311\Lib\site-packages\imageio\__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File c:\Python311\Lib\site-packages\imageio\v2.py:359, in imread(uri, format, **kwargs)
#     356 imopen_args = decypher_format_arg(format)
#     357 imopen_args["legacy_mode"] = True
# --> 359 with imopen(uri, "ri", **imopen_args) as file:
#     360     result = file.read(index=0, **kwargs)
#     362 return result
#
# File c:\Python311\Lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File c:\Python311\Lib\site-packages\imageio\core\request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File c:\Python311\Lib\site-packages\imageio\core\request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'd:\Study\code\NeurIPS2023-OpenReviewData\asset\logo.png'

# %% [markdown]
# ## Rating Distributions

# %%
ratings = pd.read_csv('ratings.tsv', sep='\t', index_col=0)
print(ratings.iloc[:, :-1].stack().mean())
ratings.head()
# Out:
# 5.367359413202934
#                0    1    2    3   4   5         decision
# paper_id
# 1Fqg133qRaI  7.0  7.0  7.0  7.0 NaN NaN  Accept (Poster)
# VVdmjgu7pKM  5.0  6.0  8.0  7.0 NaN NaN  Accept (Poster)
# -Lr-u0b42he  7.0  5.0  6.0  6.0 NaN NaN  Accept (Poster)
# dKwmCtp6YI   3.0  4.0  5.0  6.0 NaN NaN           Reject
# WoLQsYU8aZ   3.0  6.0  5.0  7.0 NaN NaN           Reject

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), gridspec_kw={'width_ratios': [1, 2]})
ratings.iloc[:, :-1].stack().value_counts().sort_index().plot.bar(
    ax=axes[0], title='ICLR 2021 Overall Ratings', xlabel='Rating', ylabel='Frequency')
ratings.iloc[:, :-1].mean(axis=1).mul(4).round().div(4).round(1).value_counts().sort_index().plot.bar(
    ax=axes[1], title='ICLR 2021 Ratings Averaged By Paper', xlabel='Avg Rating', ylabel='# Papers')
plt.tight_layout()
plt.savefig('asset/ratings_dist.png', dpi=300, bbox_inches='tight')

# %%
data = {}
for keywords, rating in zip(df.keywords, ratings.iloc[:, :-1].mean(axis=1)):
    if (isinstance(keywords, float) and np.isnan(keywords)) or np.isnan(rating):
        continue
    for keyword in keywords.lower().replace('-', ' ').replace('networks', 'network').split(','):
        data.setdefault(keyword.strip(), []).append(rating)

t = pd.DataFrame({
    'Frequency': [min(len(v), 50) for v in data.values()], # clip to 50
    'AverageRating': [np.mean(v) for v in data.values()],
    'Keyword': list(data.keys())
}).query('Frequency>9')
t.plot.scatter(x='Frequency', y='AverageRating', figsize=(16, 12))

for i in range(len(t)):
     plt.text(t.Frequency.iloc[i], t.AverageRating.iloc[i], t.Keyword.iloc[i], 
              horizontalalignment='left', 
              size='small', color='black', alpha=0.6)

plt.tight_layout()
plt.savefig('asset/keyword_ratings.png', dpi=300, bbox_inches='tight')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Top 50 Papers

# %%
comb_df = pd.DataFrame({
    'AvgRating': ratings.iloc[:, :-1].mean(axis=1).round(2),
    'Title': '[' + df['title'] + ']' + '(' + df['link'] + ')',
    'Ratings': ratings.iloc[:, :-1].apply(lambda x: ', '.join(x.dropna().astype(int).astype(str).values), axis=1),
    'Decision': ratings.iloc[:, -1],
})

comb_df = comb_df.sort_values('AvgRating', ascending=False).reset_index(drop=True)
comb_df.index += 1
comb_df.index.name = 'Rank'
comb_df.head(50)
# Out:
#       AvgRating                                              Title  \
# Rank
# 1          8.75  [How Neural Networks Extrapolate: From Feedfor...
# 2          8.33  [Dataset Condensation with Gradient Matching](...
# 3          8.25  [Learning Flexible Visual Representations via ...
# 4          8.25  [Towards Nonlinear Disentanglement in Natural ...
# 5          8.00  [Deformable DETR: Deformable Transformers for ...
# 6          8.00  [Learning a Latent Simplex in Input Sparsity T...
# 7          8.00  [Augmenting Physical Models with Deep Networks...
# 8          8.00  [What Matters for On-Policy Deep Actor-Critic ...
# 9          8.00  [Parameterization of Hypercomplex Multiplicati...
# 10         8.00  [Scalable Learning and MAP Inference for Nonsy...
# 11         8.00  [Score-Based Generative Modeling through Stoch...
# 12         8.00  [Complex Query Answering with Neural Link Pred...
# 13         8.00  [Deep symbolic regression: Recovering mathemat...
# 14         8.00  [On the mapping between Hopfield networks and ...
# 15         8.00  [Theoretical Analysis of Self-Training with De...
# 16         7.75  [Share or Not? Learning to Schedule Language-S...
# 17         7.75  [Autoregressive Entity Retrieval](https://open...
# 18         7.75  [Expressive Power of Invariant and Equivariant...
# 19         7.75  [Learning Cross-Domain Correspondence for Cont...
# 20         7.75  [Rethinking Architecture Selection in Differen...
# 21         7.75  [Learning Mesh-Based Simulation with Graph Net...
# 22         7.67  [Distributional Sliced-Wasserstein and Applica...
# 23         7.67  [Predicting Infectiousness for Proactive Conta...
# 24         7.67  [Neural Synthesis of Binaural Audio](https://o...
# 25         7.67  [When Do Curricula Work?](https://openreview.n...
# 26         7.67  [Do 2D GANs know 3D shape? Unsupervised 3D Sha...
# 27         7.67  [EigenGame: PCA as a Nash Equilibrium](https:/...
# 28         7.67  [Extreme Memorization via Scale of Initializat...
# 29         7.67  [Invariant Representations for Reinforcement L...
# 30         7.67  [Geometry-aware Instance-reweighted Adversaria...
# 31         7.60  [Optimal Rates for Averaged Stochastic Gradien...
# 32         7.60  [DiffWave: A Versatile Diffusion Model for Aud...
# 33         7.50  [Learning with feature dependent label noise: ...
# 34         7.50  [Very Deep VAEs Generalize Autoregressive Mode...
# 35         7.50  [Global Convergence of Three-layer Neural Netw...
# 36         7.50  [Rethinking the Role of Gradient-based Attribu...
# 37         7.50  [Gradient Projection Memory for Continual Lear...
# 38         7.50  [Conditional Generative Modeling via Learning ...
# 39         7.50  [Learning to Reach Goals via Iterated Supervis...
# 40         7.50  [The Traveling Observer Model: Multi-task Lear...
# 41         7.50  [Learning-based Support Estimation in Sublinea...
# 42         7.50  [Human-Level Performance in No-Press Diplomacy...
# 43         7.50  [Parrot: Data-Driven Behavioral Priors for Rei...
# 44         7.50  [Recurrent Independent Mechanisms](https://ope...
# 45         7.50  [Rethinking Attention with Performers](https:/...
# 46         7.50  [Implicit Normalizing Flows](https://openrevie...
# 47         7.50  [Randomized Automatic Differentiation](https:/...
# 48         7.50  [Grounded Language Learning Fast and Slow](htt...
# 49         7.50  [Correcting experience replay for multi-agent ...
# 50         7.50  [What are the Statistical Limits of Batch RL w...
#
#             Ratings            Decision
# Rank
# 1        9, 9, 9, 8       Accept (Oral)
# 2           8, 9, 8       Accept (Oral)
# 3        9, 8, 8, 8       Accept (Oral)
# 4        7, 9, 8, 9       Accept (Oral)
# 5        9, 8, 8, 7       Accept (Oral)
# 6           7, 9, 8  Accept (Spotlight)
# 7           9, 7, 8       Accept (Oral)
# 8        7, 9, 9, 7       Accept (Oral)
# 9           8, 8, 8  Accept (Spotlight)
# 10          9, 7, 8       Accept (Oral)
# 11       8, 9, 7, 8       Accept (Oral)
# 12       9, 6, 8, 9       Accept (Oral)
# 13       8, 7, 8, 9       Accept (Oral)
# 14         10, 7, 7       Accept (Oral)
# 15       9, 7, 9, 7       Accept (Oral)
# 16       7, 9, 7, 8       Accept (Oral)
# 17       7, 8, 8, 8  Accept (Spotlight)
# 18       8, 8, 6, 9  Accept (Spotlight)
# 19      6, 8, 7, 10       Accept (Oral)
# 20      7, 10, 7, 7       Accept (Oral)
# 21      9, 6, 6, 10  Accept (Spotlight)
# 22          9, 7, 7  Accept (Spotlight)
# 23          9, 7, 7  Accept (Spotlight)
# 24          7, 9, 7       Accept (Oral)
# 25          8, 8, 7       Accept (Oral)
# 26          8, 7, 8       Accept (Oral)
# 27          8, 8, 7       Accept (Oral)
# 28          7, 7, 9     Accept (Poster)
# 29          7, 7, 9       Accept (Oral)
# 30          7, 8, 8       Accept (Oral)
# 31    7, 8, 8, 8, 7       Accept (Oral)
# 32    7, 7, 9, 8, 7       Accept (Oral)
# 33       7, 8, 7, 8  Accept (Spotlight)
# 34       7, 8, 8, 7  Accept (Spotlight)
# 35       9, 7, 7, 7       Accept (Oral)
# 36       9, 9, 7, 5       Accept (Oral)
# 37       8, 8, 6, 8       Accept (Oral)
# 38      7, 6, 10, 7     Accept (Poster)
# 39       7, 8, 7, 8       Accept (Oral)
# 40       6, 6, 9, 9  Accept (Spotlight)
# 41       7, 8, 8, 7  Accept (Spotlight)
# 42       7, 8, 7, 8       Accept (Oral)
# 43       9, 6, 7, 8       Accept (Oral)
# 44       9, 7, 7, 7  Accept (Spotlight)
# 45       7, 8, 8, 7       Accept (Oral)
# 46       8, 7, 7, 8  Accept (Spotlight)
# 47       7, 8, 8, 7       Accept (Oral)
# 48       8, 6, 8, 8  Accept (Spotlight)
# 49       8, 8, 7, 7  Accept (Spotlight)
# 50       8, 7, 8, 7  Accept (Spotlight)

# %%
# with open('ranked_papers.md', 'w', encoding='utf8') as f:
#     comb_df.to_markdown(f)
